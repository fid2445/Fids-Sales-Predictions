# %% [markdown]
# <a href="https://colab.research.google.com/github/fid2445/Fids-Sales-Predictions/blob/main/GroupByPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
filename = ('https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data', header = None)

# %%
df.head()
# Out:
#    0         1         2  3
# 0  7  07/24/05  00:00:00  0
# 1  9  07/24/05  00:00:00  0
# 2  7  07/24/05  00:30:00  1
# 3  9  07/24/05  00:30:00  0
# 4  7  07/24/05  01:00:00  0

# %%
df.columns = ['Flow_ID',
             'Date',
             'Time',
             'Count']

# %%
df.head()
# Out:
#    Flow_ID      Date      Time  Count
# 0        7  07/24/05  00:00:00      0
# 1        9  07/24/05  00:00:00      0
# 2        7  07/24/05  00:30:00      1
# 3        9  07/24/05  00:30:00      0
# 4        7  07/24/05  01:00:00      0

# %%
outflow_filter = df['Flow_ID'] == 7
date = df['Date'] == '07/24/05'

# %%
df = df.loc[outflow_filter & date, :]
df
# Out:
#     Flow_ID      Date      Time  Count
# 0         7  07/24/05  00:00:00      0
# 2         7  07/24/05  00:30:00      1
# 4         7  07/24/05  01:00:00      0
# 6         7  07/24/05  01:30:00      0
# 8         7  07/24/05  02:00:00      0
# 10        7  07/24/05  02:30:00      2
# 12        7  07/24/05  03:00:00      0
# 14        7  07/24/05  03:30:00      0
# 16        7  07/24/05  04:00:00      0
# 18        7  07/24/05  04:30:00      0
# 20        7  07/24/05  05:00:00      0
# 22        7  07/24/05  05:30:00      0
# 24        7  07/24/05  06:00:00      0
# 26        7  07/24/05  06:30:00      0
# 28        7  07/24/05  07:00:00      0
# 30        7  07/24/05  07:30:00      2
# 32        7  07/24/05  08:00:00      0
# 34        7  07/24/05  08:30:00      0
# 36        7  07/24/05  09:00:00      0
# 38        7  07/24/05  09:30:00      1
# 40        7  07/24/05  10:00:00      0
# 42        7  07/24/05  10:30:00      0
# 44        7  07/24/05  11:00:00      1
# ...

# %%
df = df['Count'].sort_values(ascending=False)

# %%
top10 = df.head(10)
top10
# Out:
# 72    4
# 84    3
# 76    2
# 92    2
# 30    2
# 10    2
# 86    2
# 70    2
# 68    1
# 74    1
# Name: Count, dtype: int64

# %%
top10
# Out:
# 72    4
# 84    3
# 76    2
# 92    2
# 30    2
# 10    2
# 86    2
# 70    2
# 68    1
# 74    1
# Name: Count, dtype: int64

# %%
a = top10.min()

# %%
# i need to come back to this part... no idea on apply functions
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-20b9b26739f6> in <module>()
# ----> 1 top10.subtract( 1 , axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     177         # validate axis
#     178         if axis is not None:
# --> 179             self._get_axis_number(axis)
#     180
#     181         res_name = get_op_result_name(self, other)
#
# ...

# %%
top10
# Out:
# 72    4
# 84    3
# 76    2
# 92    2
# 30    2
# 10    2
# 86    2
# 70    2
# 68    1
# 74    1
# Name: Count, dtype: int64
